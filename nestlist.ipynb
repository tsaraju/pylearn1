# %%
students = [
["Rahul", 21, "Python"],
["Priya", 22, "Data Science"],
["Aman", 20, "Machine Learning"]
]

# %%
#Print the complete list
students
# Out:
# [['Rahul', 21, 'Python'],
#  ['Priya', 22, 'Data Science'],
#  ['Aman', 20, 'Machine Learning']]

# %%
#Print Rahul's name
students[0][0]
# Out:
# 'Rahul'

# %%
#Print Priya's age
students[1][1]
# Out:
# 22

# %%
#Print Aman's course
students[2][2]
# Out:
# 'Machine Learning'

# %%
#Print the complete record of Priya
students[1][0:]
# Out:
# ['Priya', 22, 'Data Science']

# %%
#Change Rahul's course to "AI"
students[0][2] = "AI"
students
# Out:
# [['Rahul', 21, 'AI'],
#  ['Priya', 22, 'Data Science'],
#  ['Aman', 20, 'Machine Learning']]

# %%
#Add another student record manually
students.extend([["Rohit", 23, "Deep Learning"]])
students
# Out:
# [['Rahul', 21, 'AI'],
#  ['Priya', 22, 'Data Science'],
#  ['Aman', 20, 'Machine Learning'],
#  ['Rohit', 23, 'Deep Learning']]
