# %%
numbers = [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
#Print the original list
numbers
# Out:
# [10, 20, 30, 20, 40, 10, 50, 30, 60]

# %%
#Convert the list into a set
set1 = set(numbers)
set1
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
#Observe which duplicates disappear
duplicates_removed = set([x for x in numbers if numbers.count(x) > 1])
duplicates_removed
# Out:
# {10, 20, 30}

# %%
#Convert the set back into a list
list1 = list(set1)
list1
# Out:
# [40, 10, 50, 20, 60, 30]

# %%
#Print the number of original elements
len(numbers)
# Out:
# 9

# %%
#Print the number of unique elements
len(list1)
# Out:
# 6

# %%
#Duplicate student names
students = ['Raju', 'Rani', 'Ramu', 'Raju', 'Rani', 'Ramu', 'Raja']

# %%
students
# Out:
# ['Raju', 'Rani', 'Ramu', 'Raju', 'Rani', 'Ramu', 'Raja']

# %%
len(students)
# Out:
# 7

# %%
set(students)
# Out:
# {'Raja', 'Raju', 'Ramu', 'Rani'}

# %%
len(set(students))
# Out:
# 4
