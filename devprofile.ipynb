# %%
#Your name
name = 'Raju'
#Age
age = 30
#City
city = 'New York'
#College/company name
company = 'Google'
#Current learning topic
concepts = ['Python', 'AI']
#Years of experience or study
exp = 15
#Whether you like Python (True/False)
interest = True
#Your expected salary after learning Python
salary = 5000.85

# %%
#Print every value.
print(f'name : {name}')
print(f'Age : {age}')
print(f'City : {city}')
print(f'Company : {company}')
print(f'Concepts : {concepts}')
print(f'Experience : {exp}')
print(f'Interest : {interest}')
print(f'Salary : {salary}')
# Out:
# name : Raju
# Age : 30
# City : New York
# Company : Google
# Concepts : ['Python', 'AI']
# Experience : 15
# Interest : True
# Salary : 5000.85

# %%
#Print the data type of every variable using type().
print(f'Type of name: {type(name)}')
print(f'Type of age: {type(age)}')
print(f'Type of city: {type(city)}')
print(f'Type of company: {type(company)}')
print(f'Type of concepts: {type(concepts)}')
print(f'Type of exp: {type(exp)}')
print(f'Type of interest: {type(interest)}')
print(f'Type of salary: {type(salary)}')
# Out:
# Type of name: <class 'str'>
# Type of age: <class 'int'>
# Type of city: <class 'str'>
# Type of company: <class 'str'>
# Type of concepts: <class 'list'>
# Type of exp: <class 'int'>
# Type of interest: <class 'bool'>
# Type of salary: <class 'float'>
