# %%
python_students = {"Rahul", "Aman", "Priya", "Karan", "Neha"}
java_students = {"Priya", "Karan", "Rohit", "Simran"}

# %%
#Print both sets
print(f'Python students : {python_students} \nJava students : {java_students}')
# Out:
# Python students : {'Priya', 'Rahul', 'Karan', 'Aman', 'Neha'}
# Java students : {'Karan', 'Priya', 'Rohit', 'Simran'}

# %%
#Find students learning either Python or Java
python_students.union(java_students)
# Out:
# {'Aman', 'Karan', 'Neha', 'Priya', 'Rahul', 'Rohit', 'Simran'}

# %%
#Find students learning both
python_students.intersection(java_students)
# Out:
# {'Karan', 'Priya'}

# %%
#Find students learning only Python
python_students.difference(java_students)
# Out:
# {'Aman', 'Neha', 'Rahul'}

# %%
#Find students learning only Java
java_students.difference(python_students)
# Out:
# {'Rohit', 'Simran'}

# %%
#Find students belonging to exactly one group
python_students.symmetric_difference(java_students)
# Out:
# {'Aman', 'Neha', 'Rahul', 'Rohit', 'Simran'}

# %%
#Add a new student
python_students.add("Anjali")
python_students
# Out:
# {'Aman', 'Anjali', 'Karan', 'Neha', 'Priya', 'Rahul'}

# %%
#Remove a student
python_students.remove("Anjali")
python_students
# Out:
# {'Aman', 'Karan', 'Neha', 'Priya', 'Rahul'}

# %%
java_students
# Out:
# {'Karan', 'Priya', 'Rohit', 'Simran'}

# %%
# Discard a student from the set
java_students.discard('Rohit')
java_students
# Out:
# {'Karan', 'Priya', 'Simran'}

# %%
# Discard a student from the set which is not present in the set never report an error
java_students.discard('Rani')
java_students
# Out:
# {'Karan', 'Priya', 'Simran'}
